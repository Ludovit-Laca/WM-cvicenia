# %% [markdown]
# 0. Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Load csv

# %%
df = pd.read_csv('/content/drive/MyDrive/Škola/WM/UNIXTIME/log_jeden_den.csv', ';', usecols=range(1,10))
df.head()
# Out:
#                ip  ...                                          useragent
# 0    193.87.12.30  ...                                   libwww-perl/6.08
# 1  23.100.232.233  ...  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 2    193.87.12.30  ...                                   libwww-perl/6.08
# 3  194.160.208.80  ...  Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:73...
# 4   109.230.62.52  ...  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:7...
#
# [5 rows x 9 columns]

# %% [markdown]
# 2. Create new column by converting datetime to unix timestamp

# %%
df['unixtime'] = pd.to_datetime(df['datetime'], format="[%d/%b/%Y:%H:%M:%S %z]")
df['unixtime'] = df['unixtime'].values.astype(np.int64) // 10 ** 9
df.head()
# Out:
#                ip  ...    unixtime
# 0    193.87.12.30  ...  1582089949
# 1  23.100.232.233  ...  1582089949
# 2    193.87.12.30  ...  1582089946
# 3  194.160.208.80  ...  1582090031
# 4   109.230.62.52  ...  1582090036
#
# [5 rows x 10 columns]

# %% [markdown]
# 3. Save to csv

# %%
df.to_csv('Laca_unixtime.csv', sep=';')
