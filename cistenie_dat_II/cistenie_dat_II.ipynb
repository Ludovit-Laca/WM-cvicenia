# %% [markdown]
# 0. Imports

# %%
import pandas as pd

# %% [markdown]
# 1. Load csv

# %%
# change to your file location
csvFile = pd.read_csv('/content/drive/MyDrive/Škola/WM/cistenie_dat_II/log_jeden_den.csv', ';', usecols=range(1,10))
csvFile
# Out:
#                  ip user userid  ...   bytes referrer         useragent
# 0      193.87.12.30    -      -  ...    7584        -                 -
# 1      193.87.12.30    -      -  ...    7584        -                 -
# 2      193.87.12.30    -      -  ...    7584        -                 -
# 3      193.87.12.30    -      -  ...    7584        -                 -
# 4      193.87.12.30    -      -  ...   20925        -  libwww-perl/6.08
# ...             ...  ...    ...  ...     ...      ...               ...
# 56511  193.87.12.30    -      -  ...    7584        -                 -
# 56512  193.87.12.30    -      -  ...  152207        -  libwww-perl/6.08
# 56513  193.87.12.30    -      -  ...  152191        -  libwww-perl/6.08
# 56514  193.87.12.30    -      -  ...    7584        -                 -
# 56515  193.87.12.30    -      -  ...    7584        -                 -
#
# [56516 rows x 9 columns]

# %% [markdown]
# 2. Check dataframe

# %%
csvFile = csvFile[~csvFile.url.str.contains('GET /navbar/')]
csvFile = csvFile[~csvFile.url.str.contains('ctrl=cron')]
csvFile
# Out:
#                    ip  ...                                          useragent
# 4        193.87.12.30  ...                                   libwww-perl/6.08
# 5      23.100.232.233  ...  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 6        193.87.12.30  ...                                   libwww-perl/6.08
# 12      35.239.58.193  ...                        ltx71 - (http://ltx71.com/)
# 15     46.229.168.140  ...  Mozilla/5.0 (compatible; SemrushBot/6~bl; +htt...
# ...               ...  ...                                                ...
# 56504  46.229.168.147  ...  Mozilla/5.0 (compatible; SemrushBot/6~bl; +htt...
# 56507    193.87.12.45  ...                            Wget/1.13.4 (linux-gnu)
# 56509  46.229.168.150  ...  Mozilla/5.0 (compatible; SemrushBot/6~bl; +htt...
# 56512    193.87.12.30  ...                                   libwww-perl/6.08
# 56513    193.87.12.30  ...                                   libwww-perl/6.08
#
# [30222 rows x 9 columns]

# %% [markdown]
# 3. Save to csv

# %%
csvFile.to_csv('Laca_cistenie_dat_II.csv', sep=';')
